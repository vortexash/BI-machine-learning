# %% [markdown]
# <a href="https://colab.research.google.com/github/vortexash/BI-machine-learning/blob/master/UnsupervisedLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url='https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
names=['sepal-length','sepal-width','petal-length','petal-width','class']
d_iris_orig=pd.read_csv(url,names=names)

# %%
d_iris_orig.head()
# Out:
#    sepal-length  sepal-width  petal-length  petal-width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
sns.scatterplot(x='sepal-length',y='sepal-width',hue='class',data=d_iris_orig)

# %%
sns.pairplot(hue='class',data=d_iris_orig)

# %%
d_iris_orig_unsupervised =d_iris_orig.drop('class',axis=1)

# %%
d_iris_orig_unsupervised
# Out:
#      sepal-length  sepal-width  petal-length  petal-width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# 5             5.4          3.9           1.7          0.4
# 6             4.6          3.4           1.4          0.3
# 7             5.0          3.4           1.5          0.2
# 8             4.4          2.9           1.4          0.2
# 9             4.9          3.1           1.5          0.1
# 10            5.4          3.7           1.5          0.2
# 11            4.8          3.4           1.6          0.2
# 12            4.8          3.0           1.4          0.1
# 13            4.3          3.0           1.1          0.1
# 14            5.8          4.0           1.2          0.2
# ...

# %%
iris_unsupervised_array=d_iris_orig_unsupervised.values
iris_unsupervised_array
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
k=3
import random
centroids=[random.choice(iris_unsupervised_array)for i in range(k)]
centroids
# Out:
# [array([4.4, 2.9, 1.4, 0.2]),
#  array([5.7, 3.8, 1.7, 0.3]),
#  array([4.6, 3.6, 1. , 0.2])]

# %%
from  scipy.spatial.distance import euclidean

# %%
#clusters=(0:[],1:[],2:[])
def assign_clusters(iris_unsupervised_array,centroids):
  clusters={i:[] for i in range(k)}# initi cluster
  for flower in iris_unsupervised_array:# iterating datasert for each flower
    min_distance=999999# init min distance
    cluster= -1 #  init closest centroid
    for i,c in enumerate(centroids):
      distance=euclidean(flower,c)# finding dist
      if distance<min_distance:# check which is smaller
        cluster =i# assign centroid if smaller
        min_distance =distance# setting minimum distance
   #  centroid=np.argmin([euclidean(flower,c)for c in centroids])   
    clusters[cluster].append(flower)
  return clusters

clusters=assign_clusters(iris_unsupervised_array,centroids) 
clusters
# Out:
# {0: [array([4.9, 3. , 1.4, 0.2]),
#   array([4.7, 3.2, 1.3, 0.2]),
#   array([4.6, 3.1, 1.5, 0.2]),
#   array([4.4, 2.9, 1.4, 0.2]),
#   array([4.9, 3.1, 1.5, 0.1]),
#   array([4.8, 3. , 1.4, 0.1]),
#   array([4.3, 3. , 1.1, 0.1]),
#   array([4.8, 3.4, 1.9, 0.2]),
#   array([5. , 3. , 1.6, 0.2]),
#   array([4.7, 3.2, 1.6, 0.2]),
#   array([4.8, 3.1, 1.6, 0.2]),
#   array([4.9, 3.1, 1.5, 0.1]),
#   array([4.9, 3.1, 1.5, 0.1]),
#   array([4.4, 3. , 1.3, 0.2]),
#   array([4.5, 2.3, 1.3, 0.3]),
#   array([4.4, 3.2, 1.3, 0.2]),
#   array([4.8, 3. , 1.4, 0.3]),
#   array([4.6, 3.2, 1.4, 0.2]),
#   array([4.9, 2.4, 3.3, 1. ]),
#   array([5. , 2. , 3.5, 1. ]),
#   array([5. , 2.3, 3.3, 1. ]),
#   array([5.1, 2.5, 3. , 1.1])],
#  1: [array([5.4, 3.9, 1.7, 0.4]),
#   array([5.4, 3.7, 1.5, 0.2]),
#   array([5.8, 4. , 1.2, 0.2]),
#   array([5.7, 4.4, 1.5, 0.4]),
#   array([5.4, 3.9, 1.3, 0.4]),
#   array([5.7, 3.8, 1.7, 0.3]),
#   array([5.1, 3.8, 1.5, 0.3]),
#   array([5.4, 3.4, 1.7, 0.2]),
# ...

# %%
def get_next_centroids(clusters):
  new_centroids =[]
  for centroid in clusters:
    new_centroids.append(np.array(clusters[centroid]).mean(axis=0))
  return new_centroids
reset_centroids(clusters)
# Out:
# [array([4.74545455, 2.91363636, 1.77727273, 0.33636364]),
#  array([6.14482759, 3.04137931, 4.37931034, 1.4612069 ]),
#  array([4.94166667, 3.43333333, 1.39166667, 0.24166667])]

# %%
def steps_K_means(iris_unsupervised_array,centroids):
  clusters= assign_clusters(iris_unsupervised_array,centroids)
  return get_next_centroids(clusters)
steps_K_means(iris_unsupervised_array,centroids)
# Out:
# [array([4.74545455, 2.91363636, 1.77727273, 0.33636364]),
#  array([6.14482759, 3.04137931, 4.37931034, 1.4612069 ]),
#  array([4.94166667, 3.43333333, 1.39166667, 0.24166667])]

# %%
from tqdm import tqdm
def K_means(iris_unsupervised_array,K,max_steps=10):
  centroids=[random.choice(iris_unsupervised_array)for i in range(k)]# init centroids
  for step in tqdm(range(max_steps)):
    centroids=steps_K_means(iris_unsupervised_array,centroids)
    return centroids

# %%
 final_centroids=K_means(iris_unsupervised_array,3,1000)
final_centroids
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# [array([5.10454545, 3.18787879, 2.01666667, 0.46818182]),
#  array([6.81136364, 3.04318182, 5.62272727, 2.00454545]),
#  array([5.9975, 2.845 , 4.5825, 1.5175])]

# %%
def get_cluster(flower):
  return np.argmin([euclidean(flower,c) for c in final_centroids ])

# %%
d_iris_orig_unsupervised=d_iris_orig_unsupervised.drop

# %%
d_iris_orig_unsupervised['cluster']= d_iris_orig_unsupervised.apply(get_cluster,asis=1)
d_iris_orig_unsupervised
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-a8d414f323b1> in <module>()
# ----> 1 d_iris_orig_unsupervised['cluster']= d_iris_orig_unsupervised.apply(get_cluster,asis=1)
#       2 d_iris_orig_unsupervised
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_standard(self)
# ...
